# %%
# A complete working python program to demostrate all
# insertion methods
# A linked list node
class Node:
    # Constructor to create a new node
    def __init__(self,data):
        self.data=data;
        self.next=None;
        self.prev=None;
# Class to create a Doubly linked list
class DoublyLinkedlist:
    # Constructor for empSty Doubly linked list:
    def __init__(self):
        self.head=None;
    # Given a refrence to the head, inserts a new node on front 
    # of list
    # Add the node at end of Doubly linked list
    def push(self,x):
        new_node=Node(x);
        new_node.next=None;
        if self.head==None:
            new_node.prev=None;
            self.head=new_node;# head holds the adress of newly 
            # created node
        else:
            new_node.next=self.head;#make a head node to point to pushed elts
            # change prev part of previous node to adress of new node
            self.head.prev=new_node
            self.head=new_node
    def insat(self,pos,new_data):# pos =1,2,3,4,5,6...
        # check wheather the  empty or not
        new_node=Node(new_data)
        if(pos==1):
            self.head=new_node;
        else:
            temp=self.head;
            for i in range(0,n-2):
                temp=temp.next;
            # shifting the nth node and placing new node at
            # nth position
            new_node.prev=temp
            x=temp.next;
            x.prev=new_node;
            new_node.next=x;
    def append(self,new_data):
        new_node=Node(new_data);
        if self.head==None:
            self.head=new_node;
        else:
            temp=self.head;
            while(temp.next):# if temp.next = None ,its true 
                # value is always false.
                temp=temp.next;
            temp.next=new_node;
            new_node.prev=temp;
    def pop_at_beg(self):
        if self.head==None:
            print("Linked list is empty")
        else:
            x=self.head
            self.head=self.head.next;
            y=x.data
            del x;
            return y
    def pop_at_end(self):
        if self.head==None:
            print("Doubly linked list is empty");
        else:
            temp=head;
            while(temp.next):
                x=temp;
                temp=temp.next;
            del temp;# deleting dinamically created memory
            x.next=None;
    def remove(self,n):# deleting elements at nth position
        if n==1:
            self.head=None;
            del head;
        else:
            temp=self.head;
            for i in range(0,n-2):
                temp=temp.next;
                if temp==None:
                    Print("No given position occured");
                    break;
            x=temp;
            y=x.next.next;
            x.next=y
            y.prev=x;
            del y
    def display(self):
        temp=self.head;
        while temp:
            print(temp.data);
            temp=temp.next

# hence doubly linked list is created successfully
# Create a doulby linked list object
x=DoublyLinkedlist();
for y in range(0,5):
    x.push(y)
k=x.pop_at_beg()

x.display()
print(k)
# Out:
# 3
# 2
# 1
# 0
# 4
